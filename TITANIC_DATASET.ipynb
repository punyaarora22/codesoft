# %%
import numpy as np
import pandas as pd
import pandas as pd

# Load the dataset
file_path = '/content/Titanic-Dataset.csv'
data = pd.read_csv(file_path)

# Explore the data
print(data.head())
print(data.info())
print(data.describe())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
import pandas as pd
from google.colab import files

# Upload the Titanic dataset CSV file using Colab's file upload feature
uploaded = files.upload()

# Check the uploaded files to ensure the dataset is uploaded correctly
for filename in uploaded.keys():
    print(f'Uploaded file: {filename}')

# Read the uploaded dataset directly by specifying the file path
file_path = '/content/Titanic-Dataset.csv'
train_data = pd.read_csv(file_path)

# Display the first few rows of the training data
train_data.head()
# Out:
#      <input type="file" id="files-0b67e357-3183-4a8b-a434-18dba2c8bf4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b67e357-3183-4a8b-a434-18dba2c8bf4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
women = train_data.loc[train_data.Sex == 'female']["Survived"]
rate_women = sum(women)/len(women)

print("% of women who survived:", rate_women)
# Out:
# % of women who survived: 0.7420382165605095

# %%
men = train_data.loc[train_data.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)

print("% of men who survived:", rate_men)
# Out:
# % of men who survived: 0.18890814558058924

# %%
from sklearn.svm import SVC

# Separate the target variable from the features
y = train_data["Survived"]

# Selecting features
features = ["Pclass", "Sex", "SibSp", "Parch"]

# Creating feature matrices
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

# Build and train the Support Vector Machine (SVM) model
svm_model = SVC(kernel='linear', C=1.0, random_state=1)
svm_model.fit(X, y)

# Make predictions using the SVM model
svm_predictions = svm_model.predict(X_test)

# Prepare output for submission
svm_output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': svm_predictions})
svm_output.to_csv('svm_submission.csv', index=False)
print("SVM submission was successfully saved!")
# Out:
# SVM submission was successfully saved!
